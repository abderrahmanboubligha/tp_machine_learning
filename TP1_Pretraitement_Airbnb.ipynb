# %%
import pandas as pd

df = pd.read_csv("../Airbnb_Open_Data.csv")
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15776\4047697357.py:3: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Airbnb_Open_Data.csv")
